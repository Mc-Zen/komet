# %%
import matplotlib.pyplot as plt

# %%
import scipy.stats
import numpy as np

data = [1, 2, 3, 9]
N = 11
x = np.linspace(0, 9, num=N)
# kde = scipy.stats.gaussian_kde(data, bw_method=3)
kde = scipy.stats.gaussian_kde(data, bw_method="scott")
print(kde.factor*np.std(x))
y = kde(x)
print(x, "\n", kde(x))
# print(kde.factor, kde.neff, sum(kde(x))*(x[1] - x[0]), "\n\n", kde(x))
# print(y)
# plt.figure(figsize=(4, 3))
# plt.plot(x, y, marker="o")
# Out:
# 2.156902486840328
# [0.  0.9 1.8 2.7 3.6 4.5 5.4 6.3 7.2 8.1 9. ]
#  [0.08231532 0.0979844  0.1059333  0.10448358 0.09490231 0.08088501
#  0.06685613 0.05602492 0.04924976 0.04522324 0.04169038]

# %%
x = [-0.9663072216374342, -0.30712783905133767, 0.35205154353475887, 1.0112309261208554, 1.670410308706952, 2.3295896912930485, 2.988769073879145, 3.647948456465242, 4.307127839051338, 4.966307221637434]
data = [1,2,3]
kde = scipy.stats.gaussian_kde(data, bw_method="scott")
print(kde(x))

  ```typ
  #let (x, y) = kde((1.0, 2.0, 3.0), num-points: 10)
  ```
  produces
  ```typ
  #(
    x: (-0.9663072216374342, -0.30712783905133767, 0.35205154353475887, 1.0112309261208554, 1.670410308706952, 2.3295896912930485, 2.988769073879145, 3.647948456465242, 4.307127839051338, 4.966307221637434),
    y: (0.0022611350153773973, 0.02818740588277772, 0.133122926583821, 0.26991677470701764, 0.3249633425699633, 0.3249633425699633, 0.2699167747070176, 0.1331229265838208, 0.028187405882777686, 0.0022611350153773978)
  )
  ```
  If I use the same x values with the scipy implementation
  ```py
  import scipy.stats
  import numpy as np
  x = [-0.9663072216374342, -0.30712783905133767, 0.35205154353475887, 1.0112309261208554, 1.670410308706952, 2.3295896912930485, 2.988769073879145, 3.647948456465242, 4.307127839051338, 4.966307221637434]
  data = [1,2,3]
  kde = scipy.stats.gaussian_kde(data, bw_method="scott")
  ```
  I get
  ```
  [0.008428   0.04669851 0.14046044 0.25092226 0.31117639 0.31117639
   0.25092226 0.14046044 0.04669851 0.008428  ]
  ```
# Out:
# [0.008428   0.04669851 0.14046044 0.25092226 0.31117639 0.31117639
#  0.25092226 0.14046044 0.04669851 0.008428  ]
